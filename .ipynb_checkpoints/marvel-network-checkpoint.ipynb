# %%
import numpy as np
import pandas as pd
from itertools import combinations
from collections import Counter

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

from IPython.display import Image
import plotly.graph_objects as go
from plotly.subplots import make_subplots

from PIL import Image

import networkx as nx

from sklearn.preprocessing import MinMaxScaler
import random
import pickle

TEMPLATE = 'simple_white'

node_df = pd.read_csv("/kaggle/input/the-marvel-universe-social-network/nodes.csv") # node & type
edge_df = pd.read_csv("/kaggle/input/the-marvel-universe-social-network/edges.csv") # hero & comic
hero_net_df = pd.read_csv("/kaggle/input/the-marvel-universe-social-network/hero-network.csv") # hero1 & hero2

# %%
temp = pd.DataFrame({'edges.csv':sorted([h for h in edge_df['hero'].unique() if 'SPIDER' in h]),
                     'hero-network.csv':sorted([h for h in hero_net_df['hero1'].unique() if 'SPIDER' in h])})

display(temp)

for c in ['hero1', 'hero2']:
    print(f"{c} name max in hero-network.csv : {max(hero_net_df[c].apply(lambda x : len(x)))}")
    

# Name Preprocessing
## only use len 20 & only use left string bas on "/"
for c in ['hero1', 'hero2']:
    hero_net_df[c] = hero_net_df[c].apply(lambda x : x[:20].split("/")[0])
edge_df['hero'] = edge_df['hero'].apply(lambda x : x[:20].split("/")[0])
# Out:
#                   edges.csv      hero-network.csv
# 0             BEACH, SPIDER         BEACH, SPIDER
# 1             BLOOD SPIDER/         BLOOD SPIDER/
# 2      MAN-SPIDER CLONE | M  MAN-SPIDER CLONE | M
# 3       MAN-SPIDER | MUTANT  MAN-SPIDER | MUTANT
# 4      SPIDER-MAN CLONE/BEN  SPIDER-MAN CLONE/BEN
# 5      SPIDER-MAN III/MARTH  SPIDER-MAN III/MARTH
# 6   SPIDER-MAN/PETER PARKER  SPIDER-MAN/PETER PAR
# 7      SPIDER-WOMAN DOPPELG  SPIDER-WOMAN DOPPELG
# 8      SPIDER-WOMAN II/JULI  SPIDER-WOMAN II/JULI
# 9      SPIDER-WOMAN IV/CHAR  SPIDER-WOMAN IV/CHAR
# 10     SPIDER-WOMAN/JESSICA  SPIDER-WOMAN/JESSICA
# 11               SPIDERCIDE            SPIDERCIDE
# 12     STEEL SPIDER/OLLIE O  STEEL SPIDER/OLLIE O
# hero1 name max in hero-network.csv : 20
# hero2 name max in hero-network.csv : 20

# %%
print("SPIDER & HULK in hero-network.csv")
print(f"hero1=SPIDER-MAN, hero2=HULK : {len(hero_net_df[(hero_net_df['hero1']=='SPIDER-MAN')&(hero_net_df['hero2']=='HULK')])}")
print(f"hero1=HULK, hero2=SPIDER-MAN : {len(hero_net_df[(hero_net_df['hero2']=='SPIDER-MAN')&(hero_net_df['hero1']=='HULK')])}")

temp1 = set(edge_df[edge_df['hero']=='SPIDER-MAN']['comic'])
temp2 = set(edge_df[edge_df['hero']=='HULK']['comic'])
print(f"Intersection in edges.csv : {len(temp1.intersection(temp2))}")
# Out:
# SPIDER & HULK in hero-network.csv
# hero1=SPIDER-MAN, hero2=HULK : 43
# hero1=HULK, hero2=SPIDER-MAN : 50
# Intersection in edges.csv : 93

# %%
topn = 25
topn_hero = edge_df.groupby(['hero'])[['comic']].count().sort_values(by=['comic'], ascending=False).head(topn).index

h1_ = []; h2_ = []; cnt_ = [];
for comb in list(combinations(topn_hero, 2)):    
    temp1 = set(edge_df[edge_df['hero']==comb[0]]['comic'])
    temp2 = set(edge_df[edge_df['hero']==comb[1]]['comic'])
    cnt = len(temp1.intersection(temp2)) # Appear Together    
    h1_.append(comb[0]); h2_.append(comb[1]); cnt_.append(cnt);
appto_df = pd.DataFrame({'H1':h1_, 'H2':h2_, 'CNT':cnt_})

display(appto_df.head())
# Out:
#            H1               H2  CNT
# 0  SPIDER-MAN  CAPTAIN AMERICA  145
# 1  SPIDER-MAN         IRON MAN   95
# 2  SPIDER-MAN            THING  125
# 3  SPIDER-MAN             THOR   96
# 4  SPIDER-MAN      HUMAN TORCH  147

# %%
HERO_COLOR = {
    'CAPTAIN AMERICA':'darkblue',
    'IRON MAN':'gold',
    'SPIDER-MAN':'darkred',
    'HULK':'forestgreen',
    'THOR':'lightblue',
    'DR. STRANGE':'purple'
}

# Make network
## Initialize graph
## - https://towardsdatascience.com/tutorial-network-visualization-basics-with-networkx-and-plotly-and-a-little-nlp-57c9bbb55bb9
marvel_net = nx.Graph() 
for i, row in appto_df.iterrows():
    marvel_net.add_edge(row['H1'], row['H2'], weight=row['CNT'])  # specify edge data

## - Inference
# aspl = nx.average_shortest_path_length(marvel_net) # no weight
# adgr = sum(dict(marvel_net.degree()).values())/float(len(marvel_net)) # no weight
        
# Visualization
## Get positions for the nodes in network
# pos_ = nx.kamada_kawai_layout(marvel_net) # sample layout : spring_layout ...
pos_ = nx.spring_layout(marvel_net, seed=11)
cent_ = nx.pagerank(marvel_net, weight='weight') # page rank
cent_top = sorted(cent_.items(), key=lambda item: item[1], reverse=True)[:1] # page rank top 1

## Custom function to create an edge between node x and node y, with a given text and width
def make_edge(x, y, text, width):
    return  go.Scatter(x=x, y=y, line=dict(width=width, color='lightgray'), hoverinfo='text', text=([text]), mode='lines')

## For each edge, make an edge_trace, append to list
edge_trace = []
for edge in marvel_net.edges():    
    if marvel_net.edges()[edge]['weight'] > 0:
        char_1 = edge[0]
        char_2 = edge[1]
        x0, y0 = pos_[char_1]
        x1, y1 = pos_[char_2]
        trace  = make_edge([x0, x1, None], [y0, y1, None], None, width=5*(marvel_net.edges()[edge]['weight']/appto_df['CNT'].max()))
        edge_trace.append(trace)
                
## Make a node trace
node_trace = go.Scatter(x=[], y=[], text=[], textposition="top center", textfont_size=10, mode='markers+text', hoverinfo='none',
                        marker=dict(color=[], size=[], line_width=[], line_color=[]))

## For each node in network, get the position and size and add to the node_trace
for node in marvel_net.nodes():
    x, y = pos_[node]
    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])
    color = 'gray'
    line_width = 2
    line_color = 'darkgray'
    name_text = node
    
    if node in HERO_COLOR:
        color = HERO_COLOR[node]; line_color='black';
        
    if node in [v[0] for v in cent_top]:
        name_text = '<b>' + node + '</b>'
        
    node_trace['marker']['color'] += tuple([color])
    node_trace['marker']['size'] += tuple([int(400*cent_[node])]) # node size is proportional to page rank
    node_trace['marker']['line_width'] += tuple([line_width])
    node_trace['marker']['line_color'] += tuple([line_color])
    node_trace['text'] += tuple([name_text])
    
    
## Customize layout
layout = go.Layout(
    paper_bgcolor='rgba(0,0,0,0)', # transparent background
    plot_bgcolor='rgba(0,0,0,0)', # transparent 2nd background
    xaxis =  {'showgrid': False, 'zeroline': False}, # no gridlines
    yaxis = {'showgrid': False, 'zeroline': False}, # no gridlines
)

## Create figure
fig = go.Figure(layout = layout)
## Add all edge traces
for trace in edge_trace:
    fig.add_trace(trace)
fig.add_trace(node_trace)
fig.update_layout(showlegend = False)
fig.update_xaxes(showticklabels = False)
fig.update_yaxes(showticklabels = False)
fig.update_layout(title=f"<b>Top {topn} Heroes Network</b>")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="76b05ff0-3677-478e-b9b4-625d3aa673bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76b05ff0-3677-478e-b9b4-625d3aa673bf")) {                    Plotly.newPlot(                        "76b05ff0-3677-478e-b9b4-625d3aa673bf",                        [{"hoverinfo":"text","line":{"color":"lightgray","width":1.0013812154696131},"mode":"lines","text":[null],"x":[0.17932918915110413,0.01695818182761856,null],"y":[-0.49109964523498817,0.13224311846215706,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6560773480662984},"mode":"lines","text":[null],"x":[0.17932918915110413,0.2261531781758647,null],"y":[-0.49109964523498817,-0.01681913206180749,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8632596685082873},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.1622422179065234,null],"y":[-0.49109964523498817,0.03157460071272584,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6629834254143646},"mode":"lines","text":[null],"x":[0.17932918915110413,0.43996902047820025,null],"y":[-0.49109964523498817,-0.04532153885137943,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.0151933701657458},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.17642964434986438,null],"y":[-0.49109964523498817,-0.1241957269776414,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8287292817679558},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.07727870299744441,null],"y":[-0.49109964523498817,-0.3027290481547731,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6422651933701657},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.28706229895684193,null],"y":[-0.49109964523498817,0.18616900705929007,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.4350828729281768},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.5719710857398749,null],"y":[-0.49109964523498817,0.27239188998547575,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6698895027624309},"mode":"lines","text":[null],"x":[0.17932918915110413,0.0766331659334106,null],"y":[-0.49109964523498817,-0.17756851021576395,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.462707182320442},"mode":"lines","text":[null],"x":[0.17932918915110413,0.17316218865244803,null],"y":[-0.49109964523498817,0.3817059318334255,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.3591160220994475},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.029940516077777042,null],"y":[-0.49109964523498817,0.49753635226688014,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.49723756906077343},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.43895768675591185,null],"y":[-0.49109964523498817,-0.1329394685705638,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":4.240331491712707},"mode":"lines","text":[null],"x":[0.17932918915110413,0.4311401860721642,null],"y":[-0.49109964523498817,-1.0,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.7113259668508287},"mode":"lines","text":[null],"x":[0.17932918915110413,0.49349672288283464,null],"y":[-0.49109964523498817,-0.36558265195867734,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.39364640883977897},"mode":"lines","text":[null],"x":[0.17932918915110413,0.39579338997437163,null],"y":[-0.49109964523498817,0.4214427508023459,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.511049723756906},"mode":"lines" ...

# %%
print(f"The number of hero pairs that never came out together : {len(appto_df[appto_df['CNT']==0])}")

cent_df = pd.DataFrame(index=list(marvel_net.nodes()))

# pagerank
cent_ = nx.pagerank(marvel_net, weight='weight')
cent_df['w_pagerank_cent'] = pd.Series(index=[k for k, v in cent_.items()], data=[float(v) for k, v in cent_.items()])

# eigenvalue centrality
cent_ = nx.eigenvector_centrality(marvel_net, weight='weight')
cent_df['w_eigenvector_cent'] = pd.Series(index=[k for k, v in cent_.items()], data=[float(v) for k, v in cent_.items()])

# degree centrality
cent_ = {h:0.0 for h in marvel_net.nodes()}
for u, v, d in marvel_net.edges(data=True):
    cent_[u]+=d['weight']; cent_[v]+=d['weight'];
cent_df['w_degree_cent'] = pd.Series(index=[k for k, v in cent_.items()], data=[float(v) for k, v in cent_.items()])

# closeness centrality
temp_net = marvel_net.copy()
for u,v,d in temp_net.edges(data=True):
    if 'distance' not in d:
        d['distance'] = 1.0/d['weight']
cent_ = nx.closeness_centrality(temp_net, distance='distance')
cent_df['w_closeness_cent'] = pd.Series(index=[k for k, v in cent_.items()], data=[float(v) for k, v in cent_.items()])

# betweenness centrality
cent_ = nx.betweenness_centrality(marvel_net, weight='weight')
cent_df['w_betweenness_cent'] = pd.Series(index=[k for k, v in cent_.items()], data=[float(v) for k, v in cent_.items()])

display(cent_df)
cent_df = cent_df.drop(columns=['w_betweenness_cent'])
# Out:
# The number of hero pairs that never came out together : 0
#                      w_pagerank_cent  w_eigenvector_cent  w_degree_cent  \
# SPIDER-MAN                  0.050127            0.145800         2874.0
# CAPTAIN AMERICA             0.066699            0.312066         4409.0
# IRON MAN                    0.054943            0.271015         3600.0
# THING                       0.057688            0.318561         3828.0
# THOR                        0.046146            0.231617         2969.0
# HUMAN TORCH                 0.056935            0.316594         3776.0
# MR. FANTASTIC               0.055603            0.313944         3689.0
# HULK                        0.029614            0.112058         1674.0
# WOLVERINE                   0.033988            0.099205         1929.0
# INVISIBLE WOMAN             0.052618            0.301620         3478.0
# SCARLET WITCH               0.050598            0.250119         3297.0
# BEAST                       0.038460            0.142554         2303.0
# DR. STRANGE                 0.022348            0.074948         1159.0
# WATSON-PARKER, MARY         0.021483            0.046779         1016.0
# DAREDEVIL                   0.020083            0.068495         1000.0
# HAWK                        0.042177            0.209054         2686.0
# VISION                      0.049297            0.244271         3201.0
# CYCLOPS                     0.033822            0.100442         1929.0
# WASP                        0.047746            0.234395         3087.0
# JAMESON, J. JONAH           0.024078            0.059494         1191.0
# ANT-MAN                     0.041392            0.205337         2633.0
# SUB-MARINER                 0.024761            0.104137         1368.0
# STORM                       0.031314            0.090441         1754.0
# PROFESSOR X                 0.030549            0.090018         1707.0
# FURY, COL. NICHOLAS         0.017534            0.063282          841.0
#
#                      w_closeness_cent  w_betweenness_cent
# SPIDER-MAN                  95.334005            0.000000
# CAPTAIN AMERICA            141.338880            0.000000
# IRON MAN                   118.305766            0.000000
# THING                      104.086414            0.000000
# THOR                       108.986186            0.000000
# HUMAN TORCH                102.769509            0.000000
# MR. FANTASTIC               99.228022            0.000000
# HULK                        79.893904            0.000000
# WOLVERINE                   71.713747            0.000000
# INVISIBLE WOMAN             96.400542            0.000000
# SCARLET WITCH              115.518830            0.000000
# BEAST                       95.134670            0.000000
# DR. STRANGE                 57.281086            0.000000
# WATSON-PARKER, MARY         82.985899            0.951691
# DAREDEVIL                   55.415187            0.000000
# HAWK                       104.502961            0.000000
# VISION                     114.231578            0.000000
# CYCLOPS                     78.295205            0.000000
# WASP                       110.232804            0.000000
# JAMESON, J. JONAH           80.946109            0.000000
# ANT-MAN                    101.696858            0.000000
# SUB-MARINER                 82.701134            0.001812
# STORM                       67.185899            0.000000
# PROFESSOR X                 68.831494            0.091787
# FURY, COL. NICHOLAS         75.652371            0.083333

# %%
# Scaling
for c in cent_df.columns:
    s = MinMaxScaler()
    cent_df[[c]] = s.fit_transform(cent_df[[c]])  
cent_df['mean_cent'] = cent_df.mean(axis=1)
cent_df = cent_df.sort_values(by=['mean_cent'], ascending=False)

# Visualization
fig = go.Figure(data=[go.Bar(
    x=cent_df.index,
    y=cent_df['mean_cent'],
    marker_color=[HERO_COLOR['CAPTAIN AMERICA']]+['lightgray']*2+\
                 [HERO_COLOR['IRON MAN']]+['lightgray']*5+\
                 [HERO_COLOR['THOR']]+['lightgray']*2+\
                 [HERO_COLOR['SPIDER-MAN']]+['lightgray']*3+\
                 [HERO_COLOR['HULK']]+['lightgray']*5+\
                 [HERO_COLOR['DR. STRANGE']]+['lightgray']*2
)])
fig.update_layout(title_text='<b>Mean Centrality of Heros</b>', template=TEMPLATE)
# Out:
# <div>                            <div id="102de42f-dce2-4085-bf1d-77c30e926339" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("102de42f-dce2-4085-bf1d-77c30e926339")) {                    Plotly.newPlot(                        "102de42f-dce2-4085-bf1d-77c30e926339",                        [{"marker":{"color":["darkblue","lightgray","lightgray","gold","lightgray","lightgray","lightgray","lightgray","lightgray","lightblue","lightgray","lightgray","darkred","lightgray","lightgray","lightgray","forestgreen","lightgray","lightgray","lightgray","lightgray","lightgray","purple","lightgray","lightgray"]},"x":["CAPTAIN AMERICA","THING","HUMAN TORCH","IRON MAN","MR. FANTASTIC","INVISIBLE WOMAN","SCARLET WITCH","VISION","WASP","THOR","HAWK","ANT-MAN","SPIDER-MAN","BEAST","CYCLOPS","WOLVERINE","HULK","STORM","SUB-MARINER","PROFESSOR X","JAMESON, J. JONAH","WATSON-PARKER, MARY","DR. STRANGE","FURY, COL. NICHOLAS","DAREDEVIL"],"y":[0.9940255373711558,0.8050841259561636,0.7919704706497447,0.7727856398810263,0.7663595912554367,0.7168327689180207,0.7021310202664827,0.6796665931465784,0.6430746029591117,0.6204849899084695,0.5466780872821179,0.5273880891913689,0.5154112365431847,0.41251433254899683,0.2749899446586894,0.25554660667814877,0.25106390585288607,0.20845513965148824,0.20582924722901028,0.20566857543322095,0.1437801413204004,0.11256073186503976,0.07810261646076122,0.07406135980517749,0.0440822222336816],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0. ...

# %%
def show_network(input_, title=""):
    input_net = input_.copy()
    
    HERO_COLOR = {
        'CAPTAIN AMERICA':'darkblue',
        'IRON MAN':'gold',
        'SPIDER-MAN':'darkred',
        'HULK':'forestgreen',
        'THOR':'lightblue',
        'DR. STRANGE':'purple'
    }

    # Visualization
    ## Get positions for the nodes in network
    pos_ = nx.spring_layout(input_net, seed=11)
    cent_ = nx.pagerank(input_net, weight='weight') # page rank
    cent_top = sorted(cent_.items(), key=lambda item: item[1], reverse=True)[:1] # page rank top 1

    ## Custom function to create an edge between node x and node y, with a given text and width
    def make_edge(x, y, text, width):
        return  go.Scatter(x=x, y=y, line=dict(width=width, color='lightgray'), hoverinfo='text', text=([text]), mode='lines')

    ## For each edge, make an edge_trace, append to list
    edge_trace = []
    for edge in input_net.edges():    
        if input_net.edges()[edge]['weight'] > 0:
            char_1 = edge[0]
            char_2 = edge[1]
            x0, y0 = pos_[char_1]
            x1, y1 = pos_[char_2]
            trace  = make_edge([x0, x1, None], [y0, y1, None], None, width=5*(input_net.edges()[edge]['weight']/appto_df['CNT'].max()))
            edge_trace.append(trace)

    ## Make a node trace
    node_trace = go.Scatter(x=[], y=[], text=[], textposition="top center", textfont_size=10, mode='markers+text', hoverinfo='none',
                            marker=dict(color=[], size=[], line_width=[], line_color=[]))

    ## For each node in network, get the position and size and add to the node_trace
    for node in input_net.nodes():
        x, y = pos_[node]
        node_trace['x'] += tuple([x])
        node_trace['y'] += tuple([y])
        color = 'gray'
        line_width = 2
        line_color = 'darkgray'
        name_text = ''

        if node in HERO_COLOR:
            color = HERO_COLOR[node]; line_color='black';
            name_text = node

        node_trace['marker']['color'] += tuple([color])
        node_trace['marker']['size'] += tuple([int(400*cent_[node])]) # node size is proportional to page rank
        node_trace['marker']['line_width'] += tuple([line_width])
        node_trace['marker']['line_color'] += tuple([line_color])
        node_trace['text'] += tuple([name_text])


    ## Customize layout
    layout = go.Layout(
        paper_bgcolor='rgba(0,0,0,0)', # transparent background
        plot_bgcolor='rgba(0,0,0,0)', # transparent 2nd background
        xaxis =  {'showgrid': False, 'zeroline': False}, # no gridlines
        yaxis = {'showgrid': False, 'zeroline': False}, # no gridlines
    )

    ## Create figure
    fig = go.Figure(layout = layout)
    ## Add all edge traces
    for trace in edge_trace:
        fig.add_trace(trace)
    fig.add_trace(node_trace)
    fig.update_layout(showlegend = False)
    fig.update_xaxes(showticklabels = False)
    fig.update_yaxes(showticklabels = False)
    fig.update_layout(title=title)
    fig.show()

# %%
# prepare test data
with open("/kaggle/input/marvel-net/all_appto.pickle", "rb") as fr:
    all_appto = pickle.load(fr)
with open("/kaggle/input/marvel-net/all_net.pickle", "rb") as fr:
    all_net = pickle.load(fr)

# # long time
# all_appto = {}
# all_net = {}
# for topn in [25, 50, 100, 200, 500]:
#     top_hero = edge_df.groupby(['hero'])[['comic']].count().sort_values(by=['comic'], ascending=False).head(topn).index

#     h1_ = []; h2_ = []; cnt_ = [];
#     for comb in list(combinations(top_hero, 2)):    
#         temp1 = set(edge_df[edge_df['hero']==comb[0]]['comic'])
#         temp2 = set(edge_df[edge_df['hero']==comb[1]]['comic'])
#         cnt = len(temp1.intersection(temp2)) # Appear Together    
#         h1_.append(comb[0]); h2_.append(comb[1]); cnt_.append(cnt);
#     appto_df = pd.DataFrame({'H1':h1_, 'H2':h2_, 'CNT':cnt_})
#     all_appto[topn] = appto_df.copy()

    
#     marvel_net = nx.Graph() 
#     for i, row in appto_df.iterrows():
#         if row['CNT'] > 0:
#             marvel_net.add_edge(row['H1'], row['H2'], weight=row['CNT'])
#     all_net[topn] = marvel_net.copy()
    
# with open("all_appto.pickle", "wb") as fw:
#     pickle.dump(all_appto, fw)
# with open("all_net.pickle", "wb") as fw:
#     pickle.dump(all_net, fw)

# %%
# Too Slow
# for topn in [25, 50, 100, 200, 500]:
#     show_network(all_net[topn], title=f"<b>Top {topn} Heroes Network</b>")
    
for topn in [25, 50, 100]:
    show_network(all_net[topn], title=f"<b>Top {topn} Heroes Network</b>")
# Out:
# <div>                            <div id="fce97dec-ce86-47f2-bff2-695128483c89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fce97dec-ce86-47f2-bff2-695128483c89")) {                    Plotly.newPlot(                        "fce97dec-ce86-47f2-bff2-695128483c89",                        [{"hoverinfo":"text","line":{"color":"lightgray","width":1.0013812154696131},"mode":"lines","text":[null],"x":[0.17932918915110413,0.01695818182761856,null],"y":[-0.49109964523498817,0.13224311846215706,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6560773480662984},"mode":"lines","text":[null],"x":[0.17932918915110413,0.2261531781758647,null],"y":[-0.49109964523498817,-0.01681913206180749,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8632596685082873},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.1622422179065234,null],"y":[-0.49109964523498817,0.03157460071272584,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6629834254143646},"mode":"lines","text":[null],"x":[0.17932918915110413,0.43996902047820025,null],"y":[-0.49109964523498817,-0.04532153885137943,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.0151933701657458},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.17642964434986438,null],"y":[-0.49109964523498817,-0.1241957269776414,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8287292817679558},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.07727870299744441,null],"y":[-0.49109964523498817,-0.3027290481547731,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6422651933701657},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.28706229895684193,null],"y":[-0.49109964523498817,0.18616900705929007,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.4350828729281768},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.5719710857398749,null],"y":[-0.49109964523498817,0.27239188998547575,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6698895027624309},"mode":"lines","text":[null],"x":[0.17932918915110413,0.0766331659334106,null],"y":[-0.49109964523498817,-0.17756851021576395,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.462707182320442},"mode":"lines","text":[null],"x":[0.17932918915110413,0.17316218865244803,null],"y":[-0.49109964523498817,0.3817059318334255,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.3591160220994475},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.029940516077777042,null],"y":[-0.49109964523498817,0.49753635226688014,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.49723756906077343},"mode":"lines","text":[null],"x":[0.17932918915110413,-0.43895768675591185,null],"y":[-0.49109964523498817,-0.1329394685705638,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":4.240331491712707},"mode":"lines","text":[null],"x":[0.17932918915110413,0.4311401860721642,null],"y":[-0.49109964523498817,-1.0,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.7113259668508287},"mode":"lines","text":[null],"x":[0.17932918915110413,0.49349672288283464,null],"y":[-0.49109964523498817,-0.36558265195867734,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.39364640883977897},"mode":"lines","text":[null],"x":[0.17932918915110413,0.39579338997437163,null],"y":[-0.49109964523498817,0.4214427508023459,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.511049723756906},"mode":"lines" ...
# <div>                            <div id="7821217f-7483-4f48-96ea-ae43094750d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7821217f-7483-4f48-96ea-ae43094750d9")) {                    Plotly.newPlot(                        "7821217f-7483-4f48-96ea-ae43094750d9",                        [{"hoverinfo":"text","line":{"color":"lightgray","width":1.0013812154696131},"mode":"lines","text":[null],"x":[0.3588984782628372,0.01502150088720632,null],"y":[0.05111020319855182,-0.08717868341404515,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6560773480662984},"mode":"lines","text":[null],"x":[0.3588984782628372,0.026759275827192383,null],"y":[0.05111020319855182,-0.09708215872352183,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8632596685082873},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.02364455044976425,null],"y":[0.05111020319855182,0.09529030518905025,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6629834254143646},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.011881493948907288,null],"y":[0.05111020319855182,-0.3017662393766353,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.0151933701657458},"mode":"lines","text":[null],"x":[0.3588984782628372,0.0156138194777202,null],"y":[0.05111020319855182,0.14072021776665766,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8287292817679558},"mode":"lines","text":[null],"x":[0.3588984782628372,0.00821303300985645,null],"y":[0.05111020319855182,0.10783560967978503,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6422651933701657},"mode":"lines","text":[null],"x":[0.3588984782628372,0.16829741663612366,null],"y":[0.05111020319855182,0.06088804221115692,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.4350828729281768},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.2924778778379649,null],"y":[0.05111020319855182,0.16350247758887468,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6698895027624309},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.017107917531492597,null],"y":[0.05111020319855182,0.14459776401220786,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.462707182320442},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.0804162350641197,null],"y":[0.05111020319855182,-0.14866788959772867,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.3591160220994475},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.2096362750082467,null],"y":[0.05111020319855182,-0.07292055533740918,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.49723756906077343},"mode":"lines","text":[null],"x":[0.3588984782628372,0.16732058681078082,null],"y":[0.05111020319855182,0.273853657694014,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":4.240331491712707},"mode":"lines","text":[null],"x":[0.3588984782628372,0.7615920380520175,null],"y":[0.05111020319855182,0.0640212513469059,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.7113259668508287},"mode":"lines","text":[null],"x":[0.3588984782628372,0.35459011579788624,null],"y":[0.05111020319855182,0.26517392721914845,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.39364640883977897},"mode":"lines","text":[null],"x":[0.3588984782628372,0.07054886826221561,null],"y":[0.05111020319855182,-0.2035311056970766,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.511049723756906},"mode":"lines","text":[null], ...
# <div>                            <div id="9e16c05c-bf2c-45f0-b780-906426d4138b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e16c05c-bf2c-45f0-b780-906426d4138b")) {                    Plotly.newPlot(                        "9e16c05c-bf2c-45f0-b780-906426d4138b",                        [{"hoverinfo":"text","line":{"color":"lightgray","width":1.0013812154696131},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.03739686302323651,null],"y":[-0.30951175559125615,-0.025733957912926635,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6560773480662984},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.06421631465866089,null],"y":[-0.30951175559125615,-0.05207173527013315,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8632596685082873},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.0841014845368331,null],"y":[-0.30951175559125615,0.015278213738459332,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6629834254143646},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.2769751947761058,null],"y":[-0.30951175559125615,0.03130460484202103,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.0151933701657458},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.039515647095395255,null],"y":[-0.30951175559125615,-0.02733067336320247,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8287292817679558},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.03410258820175349,null],"y":[-0.30951175559125615,0.02505951580514398,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6422651933701657},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.11714573937300073,null],"y":[-0.30951175559125615,-0.08737254964649625,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.4350828729281768},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.23589512970284313,null],"y":[-0.30951175559125615,0.19323440844505274,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6698895027624309},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.03654159186938539,null],"y":[-0.30951175559125615,0.032407944771628304,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.462707182320442},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.09912886738298202,null],"y":[-0.30951175559125615,0.033299953316951264,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.3591160220994475},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.15259716142521007,null],"y":[-0.30951175559125615,0.14969339402789456,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.49723756906077343},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.16885118563090856,null],"y":[-0.30951175559125615,-0.134458461047214,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":4.240331491712707},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.0675485954444286,null],"y":[-0.30951175559125615,-0.558899710303147,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.7113259668508287},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.04218999054786515,null],"y":[-0.30951175559125615,-0.29234535496544906,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.39364640883977897},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.12879610853578916,null],"y":[-0.30951175559125615,0.007995680293572501,null],"type":"scatter"},{"hoverinfo":"text","line":{"color" ...

# %%
def get_cent(input_net):
    marvel_net = input_net.copy()
    cent_df = pd.DataFrame(index=list(marvel_net.nodes()))

    # pagerank
    cent_ = nx.pagerank(marvel_net, weight='weight')
    cent_df['w_pagerank_cent'] = pd.Series(index=[k for k, v in cent_.items()], data=[float(v) for k, v in cent_.items()])

    # eigenvalue centrality
    cent_ = nx.eigenvector_centrality(marvel_net, weight='weight')
    cent_df['w_eigenvector_cent'] = pd.Series(index=[k for k, v in cent_.items()], data=[float(v) for k, v in cent_.items()])

    # degree centrality
    cent_ = {h:0.0 for h in marvel_net.nodes()}
    for u, v, d in marvel_net.edges(data=True):
        cent_[u]+=d['weight']; cent_[v]+=d['weight'];
    cent_df['w_degree_cent'] = pd.Series(index=[k for k, v in cent_.items()], data=[float(v) for k, v in cent_.items()])

    # closeness centrality
    temp_net = marvel_net.copy()
    for u,v,d in temp_net.edges(data=True):
        if 'distance' not in d:
            if d['weight'] != 0:
                d['distance'] = 1.0/d['weight']
            else:
                d['distance'] = 2
    cent_ = nx.closeness_centrality(temp_net, distance='distance')
    cent_df['w_closeness_cent'] = pd.Series(index=[k for k, v in cent_.items()], data=[float(v) for k, v in cent_.items()])

#     # betweenness centrality
#     cent_ = nx.betweenness_centrality(marvel_net, weight='weight')
#     cent_df['w_betweenness_cent'] = pd.Series(index=[k for k, v in cent_.items()], data=[float(v) for k, v in cent_.items()])
    # Scaling
    for c in cent_df.columns:
        s = MinMaxScaler()
        cent_df[[c]] = s.fit_transform(cent_df[[c]])  
    cent_df['mean_cent'] = cent_df.mean(axis=1)
    cent_df = cent_df.sort_values(by=['mean_cent'], ascending=False)

    return cent_df

# prepare Data
mean_cent_df = pd.DataFrame(index=HERO_COLOR.keys())
for topn in [25, 50, 100, 200, 500]:
    mean_cent_df[f"mean_cent_{topn}"] = get_cent(all_net[topn]).loc[HERO_COLOR.keys(), :]['mean_cent']
    
# visualization
fig = go.Figure()
for c in mean_cent_df.T.columns:
    temp_ = mean_cent_df.T[c]
    fig.add_trace(go.Scatter(x=[f"In Top {n} Heroes" for n in [25, 50, 100, 200, 500]], y=temp_, mode='lines+markers', name=c,
                             line=dict(color=HERO_COLOR[c])
                            ))

fig.update_layout(title_text='<b>Mean Centrality</b>', template=TEMPLATE)
fig.show()
# Out:
# <div>                            <div id="417dcf9b-152d-4332-9e8e-33484ce1421d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("417dcf9b-152d-4332-9e8e-33484ce1421d")) {                    Plotly.newPlot(                        "417dcf9b-152d-4332-9e8e-33484ce1421d",                        [{"line":{"color":"darkblue"},"mode":"lines+markers","name":"CAPTAIN AMERICA","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[0.9940255373711558,1.0,1.0,1.0,1.0],"type":"scatter"},{"line":{"color":"gold"},"mode":"lines+markers","name":"IRON MAN","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[0.7727856398810263,0.7970206033903262,0.8158196759472323,0.8183390298651214,0.8127377619642885],"type":"scatter"},{"line":{"color":"darkred"},"mode":"lines+markers","name":"SPIDER-MAN","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[0.5154112365431847,0.6280939424892565,0.6972670605806405,0.7371212613635265,0.7835474743535112],"type":"scatter"},{"line":{"color":"forestgreen"},"mode":"lines+markers","name":"HULK","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[0.25106390585288607,0.3959556305574969,0.5015300118223931,0.5393863127711072,0.5522632792891717],"type":"scatter"},{"line":{"color":"lightblue"},"mode":"lines+markers","name":"THOR","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[0.6204849899084695,0.7116522830789005,0.7987722257308384,0.802207915855937,0.7883227389456],"type":"scatter"},{"line":{"color":"purple"},"mode":"lines+markers","name":"DR. STRANGE","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[0.07810261646076122,0.23712961310883932,0.35014045668099714,0.3935947414903824,0.4350185057978523],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth ...

# %%
# prepare data
ncr_ = []; spl_ = []; dia_ = []; rad_ = [];
for n in [25, 50, 100, 200, 500]:
    test_appto = all_appto[n].copy()
    test_net = all_net[n].copy()

    ncr_.append(len(test_appto[test_appto['CNT']==0])/len(test_appto))
    spl_.append(nx.average_shortest_path_length(test_net))
    dia_.append(nx.diameter(test_net))
    rad_.append(nx.radius(test_net))
ch_df = pd.DataFrame({'Heroes':[25, 50, 100, 200, 500], 'Non-Connection Ratio':ncr_, 'Avg Shortest Path Length':spl_, 'Diameter':dia_, 'Radius':rad_})

# visualization
fig = make_subplots(specs=[[{"secondary_y": True}]])
for c in ['Non-Connection Ratio', 'Avg Shortest Path Length', 'Diameter', 'Radius']:
    temp_ = ch_df[c]
    if c == 'Non-Connection Ratio':
        fig.add_trace(go.Scatter(x=[f"In Top {n} Heroes" for n in [25, 50, 100, 200, 500]], y=temp_, name=c, line=dict(color='darkgray')),
                      secondary_y=True)
    else:
        fig.add_trace(go.Bar(x=[f"In Top {n} Heroes" for n in [25, 50, 100, 200, 500]], y=temp_, name=c
                                ))

fig.update_layout(barmode='group')
fig.update_yaxes(title_text="length", secondary_y=False)
fig.update_yaxes(title_text="ratio", secondary_y=True)
fig.update_layout(title_text='<b>Changes in Network Characteristics according to the number of heroes</b>', template=TEMPLATE)
fig.show()
# Out:
# <div>                            <div id="ef113cfb-e9ec-4c87-839d-aa09f3593502" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef113cfb-e9ec-4c87-839d-aa09f3593502")) {                    Plotly.newPlot(                        "ef113cfb-e9ec-4c87-839d-aa09f3593502",                        [{"line":{"color":"darkgray"},"name":"Non-Connection Ratio","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[0.0,0.024489795918367346,0.17454545454545456,0.3935175879396985,0.7191983967935872],"type":"scatter","xaxis":"x","yaxis":"y2"},{"name":"Avg Shortest Path Length","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[1.0,1.0244897959183674,1.1745454545454546,1.3935175879396986,1.7222204408817636],"type":"bar"},{"name":"Diameter","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[1,2,2,2,3],"type":"bar"},{"name":"Radius","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[1,1,1,2,2],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)" ...

# %%
# prepare data
min_node_ = []; r_ = [];
for n in [25, 50, 100, 200, 500]:
    test_appto = all_appto[n].copy()
    test_net = all_net[n].copy()

    cnt = len(nx.minimum_node_cut(test_net))
    min_node_.append(cnt)
    r_.append(cnt/n)
ch_df = pd.DataFrame({'Heroes':[25, 50, 100, 200, 500], 'Number of Nodes':min_node_, 'Cut Node Ratio':r_})

# visualization
fig = make_subplots(specs=[[{"secondary_y": True}]])
for c in ['Number of Nodes', 'Cut Node Ratio']:
    temp_ = ch_df[c]
    if c == 'Cut Node Ratio':
        fig.add_trace(go.Scatter(x=[f"In Top {n} Heroes" for n in [25, 50, 100, 200, 500]], y=temp_, name=c, line=dict(color='darkgray')),
                      secondary_y=True)
    else:
        fig.add_trace(go.Bar(x=[f"In Top {n} Heroes" for n in [25, 50, 100, 200, 500]], y=temp_, name=c
                                ))

fig.update_layout(barmode='group')
fig.update_yaxes(title_text="count", secondary_y=False)
fig.update_yaxes(title_text="ratio", secondary_y=True)
fig.update_layout(title_text="<b>Changes in Network's Robustness according to the number of heroes</b>", template=TEMPLATE)
fig.show()

test_appto = all_appto[500].copy()
print(f"Unconnected proportion of 500 hero pairs : {len(test_appto[test_appto['CNT']==0]) / len(test_appto):.3f}")
# Out:
# <div>                            <div id="f6ef2b8d-2813-4ebc-8855-a9b1a0320e53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6ef2b8d-2813-4ebc-8855-a9b1a0320e53")) {                    Plotly.newPlot(                        "f6ef2b8d-2813-4ebc-8855-a9b1a0320e53",                        [{"name":"Number of Nodes","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[24,41,40,7,8],"type":"bar"},{"line":{"color":"darkgray"},"name":"Cut Node Ratio","x":["In Top 25 Heroes","In Top 50 Heroes","In Top 100 Heroes","In Top 200 Heroes","In Top 500 Heroes"],"y":[0.96,0.82,0.4,0.035,0.016],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar": ...
# Unconnected proportion of 500 hero pairs : 0.719

# %%
topn = 100
top_hero = edge_df.groupby(['hero'])[['comic']].count().sort_values(by=['comic'], ascending=False).head(topn).index
top_hero = [h for i, h in enumerate(top_hero) if i%2 == 0] # after finger snap

h1_ = []; h2_ = []; cnt_ = [];
for comb in list(combinations(top_hero, 2)):    
    temp1 = set(edge_df[edge_df['hero']==comb[0]]['comic'])
    temp2 = set(edge_df[edge_df['hero']==comb[1]]['comic'])
    cnt = len(temp1.intersection(temp2)) # Appear Together    
    h1_.append(comb[0]); h2_.append(comb[1]); cnt_.append(cnt);
appto_df = pd.DataFrame({'H1':h1_, 'H2':h2_, 'CNT':cnt_})
all_appto['fs50'] = appto_df.copy()


marvel_net = nx.Graph() 
for i, row in appto_df.iterrows():
    if row['CNT'] > 0:
        marvel_net.add_edge(row['H1'], row['H2'], weight=row['CNT'])
all_net['fs50'] = marvel_net.copy()

for topn in [100, 'fs50', 50]:
    show_network(all_net[topn], title=f"<b>Top {topn} Heroes Network</b>")
# Out:
# <div>                            <div id="0caf4324-2250-4872-9d45-9860ed706170" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0caf4324-2250-4872-9d45-9860ed706170")) {                    Plotly.newPlot(                        "0caf4324-2250-4872-9d45-9860ed706170",                        [{"hoverinfo":"text","line":{"color":"lightgray","width":1.7018779342723005},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.03739686302323651,null],"y":[-0.30951175559125615,-0.025733957912926635,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.1150234741784038},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.06421631465866089,null],"y":[-0.30951175559125615,-0.05207173527013315,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.467136150234742},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.0841014845368331,null],"y":[-0.30951175559125615,0.015278213738459332,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.1267605633802817},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.2769751947761058,null],"y":[-0.30951175559125615,0.03130460484202103,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.7253521126760563},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.039515647095395255,null],"y":[-0.30951175559125615,-0.02733067336320247,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.4084507042253522},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.03410258820175349,null],"y":[-0.30951175559125615,0.02505951580514398,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.0915492957746478},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.11714573937300073,null],"y":[-0.30951175559125615,-0.08737254964649625,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.7394366197183099},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.23589512970284313,null],"y":[-0.30951175559125615,0.19323440844505274,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.1384976525821597},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.03654159186938539,null],"y":[-0.30951175559125615,0.032407944771628304,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.7863849765258215},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.09912886738298202,null],"y":[-0.30951175559125615,0.033299953316951264,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6103286384976526},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.15259716142521007,null],"y":[-0.30951175559125615,0.14969339402789456,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8450704225352113},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.16885118563090856,null],"y":[-0.30951175559125615,-0.134458461047214,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":7.206572769953051},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.0675485954444286,null],"y":[-0.30951175559125615,-0.558899710303147,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.2089201877934272},"mode":"lines","text":[null],"x":[-0.009374434629699493,-0.04218999054786515,null],"y":[-0.30951175559125615,-0.29234535496544906,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6690140845070423},"mode":"lines","text":[null],"x":[-0.009374434629699493,0.12879610853578916,null],"y":[-0.30951175559125615,0.007995680293572501,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":" ...
# <div>                            <div id="88f0c8d3-36e5-4f43-a3bd-6cbea8060bef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88f0c8d3-36e5-4f43-a3bd-6cbea8060bef")) {                    Plotly.newPlot(                        "88f0c8d3-36e5-4f43-a3bd-6cbea8060bef",                        [{"hoverinfo":"text","line":{"color":"lightgray","width":1.1150234741784038},"mode":"lines","text":[null],"x":[-0.29823515284701246,0.19044492061651297,null],"y":[-0.04624387653869761,-0.10060461481947329,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.1267605633802817},"mode":"lines","text":[null],"x":[-0.29823515284701246,0.1240208565979591,null],"y":[-0.04624387653869761,-0.3259593568316691,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.4084507042253522},"mode":"lines","text":[null],"x":[-0.29823515284701246,-0.03868118586320234,null],"y":[-0.04624387653869761,0.03521326037449922,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.7394366197183099},"mode":"lines","text":[null],"x":[-0.29823515284701246,-0.02860132223167453,null],"y":[-0.04624387653869761,0.3213999093755639,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.7863849765258215},"mode":"lines","text":[null],"x":[-0.29823515284701246,0.15216561533812137,null],"y":[-0.04624387653869761,-0.11795699107935056,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8450704225352113},"mode":"lines","text":[null],"x":[-0.29823515284701246,-0.17333963300899724,null],"y":[-0.04624387653869761,-0.1677082500481255,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.2089201877934272},"mode":"lines","text":[null],"x":[-0.29823515284701246,-0.36841591935351203,null],"y":[-0.04624387653869761,-0.2081845609330827,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8685446009389672},"mode":"lines","text":[null],"x":[-0.29823515284701246,0.10780371431771853,null],"y":[-0.04624387653869761,-0.0597498695142588,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.9154929577464789},"mode":"lines","text":[null],"x":[-0.29823515284701246,0.026750851469629577,null],"y":[-0.04624387653869761,-0.11379028988419611,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.539906103286385},"mode":"lines","text":[null],"x":[-0.29823515284701246,0.16799171622281794,null],"y":[-0.04624387653869761,-0.2094165516737023,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.4929577464788732},"mode":"lines","text":[null],"x":[-0.29823515284701246,0.03049127314520758,null],"y":[-0.04624387653869761,0.40949117049575995,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.3873239436619718},"mode":"lines","text":[null],"x":[-0.29823515284701246,0.2056903689885804,null],"y":[-0.04624387653869761,0.19893459390369356,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.528169014084507},"mode":"lines","text":[null],"x":[-0.29823515284701246,-0.07522722402153059,null],"y":[-0.04624387653869761,0.408911479154487,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.41079812206572774},"mode":"lines","text":[null],"x":[-0.29823515284701246,-0.21704482110657353,null],"y":[-0.04624387653869761,0.39611704210641757,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6807511737089201},"mode":"lines","text":[null],"x":[-0.29823515284701246,0.09096067589148378,null],"y":[-0.04624387653869761,0.06813016422914317,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.45 ...
# <div>                            <div id="76db8444-90ab-4edf-a32c-135300940fa5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76db8444-90ab-4edf-a32c-135300940fa5")) {                    Plotly.newPlot(                        "76db8444-90ab-4edf-a32c-135300940fa5",                        [{"hoverinfo":"text","line":{"color":"lightgray","width":1.7018779342723005},"mode":"lines","text":[null],"x":[0.3588984782628372,0.01502150088720632,null],"y":[0.05111020319855182,-0.08717868341404515,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.1150234741784038},"mode":"lines","text":[null],"x":[0.3588984782628372,0.026759275827192383,null],"y":[0.05111020319855182,-0.09708215872352183,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.467136150234742},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.02364455044976425,null],"y":[0.05111020319855182,0.09529030518905025,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.1267605633802817},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.011881493948907288,null],"y":[0.05111020319855182,-0.3017662393766353,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.7253521126760563},"mode":"lines","text":[null],"x":[0.3588984782628372,0.0156138194777202,null],"y":[0.05111020319855182,0.14072021776665766,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.4084507042253522},"mode":"lines","text":[null],"x":[0.3588984782628372,0.00821303300985645,null],"y":[0.05111020319855182,0.10783560967978503,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.0915492957746478},"mode":"lines","text":[null],"x":[0.3588984782628372,0.16829741663612366,null],"y":[0.05111020319855182,0.06088804221115692,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.7394366197183099},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.2924778778379649,null],"y":[0.05111020319855182,0.16350247758887468,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.1384976525821597},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.017107917531492597,null],"y":[0.05111020319855182,0.14459776401220786,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.7863849765258215},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.0804162350641197,null],"y":[0.05111020319855182,-0.14866788959772867,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6103286384976526},"mode":"lines","text":[null],"x":[0.3588984782628372,-0.2096362750082467,null],"y":[0.05111020319855182,-0.07292055533740918,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8450704225352113},"mode":"lines","text":[null],"x":[0.3588984782628372,0.16732058681078082,null],"y":[0.05111020319855182,0.273853657694014,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":7.206572769953051},"mode":"lines","text":[null],"x":[0.3588984782628372,0.7615920380520175,null],"y":[0.05111020319855182,0.0640212513469059,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":1.2089201877934272},"mode":"lines","text":[null],"x":[0.3588984782628372,0.35459011579788624,null],"y":[0.05111020319855182,0.26517392721914845,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.6690140845070423},"mode":"lines","text":[null],"x":[0.3588984782628372,0.07054886826221561,null],"y":[0.05111020319855182,-0.2035311056970766,null],"type":"scatter"},{"hoverinfo":"text","line":{"color":"lightgray","width":0.8685446009389672},"mode":"lines","text":[null]," ...

# %%
test_mean_cent_df = pd.DataFrame()
for topn in [50, 'fs50']:
    test_mean_cent_df[f"mean_cent_{topn}"] = get_cent(all_net[topn]).loc[:, :]['mean_cent']

print("<The existing 50 Hero Network>")
display(test_mean_cent_df[["mean_cent_50"]].sort_values(by=["mean_cent_50"], ascending=False).head(10))

print("<50 Hero Networks After Finger Snap>")
display(test_mean_cent_df[["mean_cent_fs50"]].sort_values(by=["mean_cent_fs50"], ascending=False).head(10))
# Out:
# <The existing 50 Hero Network>
#                  mean_cent_50
# CAPTAIN AMERICA      1.000000
# IRON MAN             0.797021
# THING                0.784713
# HUMAN TORCH          0.773303
# SCARLET WITCH        0.767129
# MR. FANTASTIC        0.753464
# VISION               0.749275
# INVISIBLE WOMAN      0.717718
# THOR                 0.711652
# WASP                 0.704862
# <50 Hero Networks After Finger Snap>
#                mean_cent_fs50
# IRON MAN             0.992999
# THOR                 0.947678
# SCARLET WITCH        0.934670
# VISION               0.930362
# WASP                 0.858847
# ANT-MAN              0.778431
# WONDER MAN           0.700660
# SPIDER-MAN           0.655756
# WOLVERINE            0.612317
# MR. FANTASTIC        0.600790

# %%
# prepare data
ncr_ = []; spl_ = []; dia_ = []; rad_ = [];
for n in [50, 'fs50']:
    test_appto = all_appto[n].copy()
    test_net = all_net[n].copy()

    ncr_.append(len(test_appto[test_appto['CNT']==0])/len(test_appto))
    spl_.append(nx.average_shortest_path_length(test_net))
    dia_.append(nx.diameter(test_net))
    rad_.append(nx.radius(test_net))
ch_df = pd.DataFrame({'Heroes':[50, 'fs50'], 'Non-Connection Ratio':ncr_, 'Avg Shortest Path Length':spl_, 'Diameter':dia_, 'Radius':rad_})

# visualization
fig = make_subplots(specs=[[{"secondary_y": True}]])
for c in ['Non-Connection Ratio', 'Avg Shortest Path Length', 'Diameter', 'Radius']:
    temp_ = ch_df[c]
    if c == 'Non-Connection Ratio':
        fig.add_trace(go.Scatter(x=[f"In Top {n} Heroes" for n in [50, 'fs50']], y=temp_, name=c, line=dict(color='darkgray')),
                      secondary_y=True)
    else:
        fig.add_trace(go.Bar(x=[f"In Top {n} Heroes" for n in [50, 'fs50']], y=temp_, name=c
                                ))

fig.update_layout(barmode='group')
fig.update_yaxes(title_text="length", secondary_y=False)
fig.update_yaxes(title_text="ratio", secondary_y=True)
fig.update_layout(title_text='<b>Changes in Network Characteristics according to the number of heroes</b>', template=TEMPLATE, height=400)
fig.show()
# Out:
# <div>                            <div id="65580954-cdf8-48a5-826f-a9e32b053e9a" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65580954-cdf8-48a5-826f-a9e32b053e9a")) {                    Plotly.newPlot(                        "65580954-cdf8-48a5-826f-a9e32b053e9a",                        [{"line":{"color":"darkgray"},"name":"Non-Connection Ratio","x":["In Top 50 Heroes","In Top fs50 Heroes"],"y":[0.024489795918367346,0.13224489795918368],"type":"scatter","xaxis":"x","yaxis":"y2"},{"name":"Avg Shortest Path Length","x":["In Top 50 Heroes","In Top fs50 Heroes"],"y":[1.0244897959183674,1.1322448979591837],"type":"bar"},{"name":"Diameter","x":["In Top 50 Heroes","In Top fs50 Heroes"],"y":[2,2],"type":"bar"},{"name":"Radius","x":["In Top 50 Heroes","In Top fs50 Heroes"],"y":[1,1],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histo ...

# %%
# prepare data
min_node_ = []; r_ = [];
for n in [50, 'fs50']:
    test_appto = all_appto[n].copy()
    test_net = all_net[n].copy()

    cnt = len(nx.minimum_node_cut(test_net))
    min_node_.append(cnt)
    r_.append(cnt/50)
ch_df = pd.DataFrame({'Heroes':[50, 'fs50'], 'Number of Nodes':min_node_, 'Cut Node Ratio':r_})

# visualization
fig = make_subplots(specs=[[{"secondary_y": True}]])
for c in ['Number of Nodes', 'Cut Node Ratio']:
    temp_ = ch_df[c]
    if c == 'Cut Node Ratio':
        fig.add_trace(go.Scatter(x=[f"In Top {n} Heroes" for n in [50, 'fs50']], y=temp_, name=c, line=dict(color='darkgray')),
                      secondary_y=True)
    else:
        fig.add_trace(go.Bar(x=[f"In Top {n} Heroes" for n in [50, 'fs50']], y=temp_, name=c
                                ))

fig.update_layout(barmode='group')
fig.update_yaxes(title_text="count", secondary_y=False)
fig.update_yaxes(title_text="ratio", secondary_y=True)
fig.update_layout(title_text="<b>Changes in Network's Robustness according to the number of heroes</b>", template=TEMPLATE, height=400)
fig.show()
# Out:
# <div>                            <div id="aadd57d8-43b8-4988-a0c1-df8f97169890" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aadd57d8-43b8-4988-a0c1-df8f97169890")) {                    Plotly.newPlot(                        "aadd57d8-43b8-4988-a0c1-df8f97169890",                        [{"name":"Number of Nodes","x":["In Top 50 Heroes","In Top fs50 Heroes"],"y":[41,23],"type":"bar"},{"line":{"color":"darkgray"},"name":"Cut Node Ratio","x":["In Top 50 Heroes","In Top fs50 Heroes"],"y":[0.82,0.46],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tick ...
